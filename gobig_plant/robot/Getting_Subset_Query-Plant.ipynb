# %%
import pandas as pd
import csv

# %%
file = pd.read_csv("GObig_plant_descriptions.csv")
file
# Out:
#              GOID ONTOLOGY                                               TERM  \
# 0      GO:0000002       BP                   mitochondrial genome maintenance
# 1      GO:0000009       MF             alpha-1,6-mannosyltransferase activity
# 2      GO:0000012       BP                         single strand break repair
# 3      GO:0000014       MF  single-stranded DNA endodeoxyribonuclease acti...
# 4      GO:0000015       CC                  phosphopyruvate hydratase complex
# ...           ...      ...                                                ...
# 10606  GO:2001289       BP                          lipid X metabolic process
# 10607  GO:2001291       BP                          codeine metabolic process
# 10608  GO:2001293       BP                      malonyl-CoA metabolic process
# 10609  GO:2001294       BP                      malonyl-CoA catabolic process
# 10610  GO:2001295       BP                   malonyl-CoA biosynthetic process
#
# ...

# %%
for index, row in file.iterrows():
    # Access individual elements of the row
    column1_value = row['LINK']  # Replace 'Column1' with the actual column name
    column2_value = row['TERM']  # Replace 'Column2' with the actual column name
    # Perform operations on each row
    print(f"{column1_value} # {column2_value}")
# Out:
# http://purl.obolibrary.org/obo/GO_0000002 # mitochondrial genome maintenance
# http://purl.obolibrary.org/obo/GO_0000009 # alpha-1,6-mannosyltransferase activity
# http://purl.obolibrary.org/obo/GO_0000012 # single strand break repair
# http://purl.obolibrary.org/obo/GO_0000014 # single-stranded DNA endodeoxyribonuclease activity
# http://purl.obolibrary.org/obo/GO_0000015 # phosphopyruvate hydratase complex
# http://purl.obolibrary.org/obo/GO_0000018 # regulation of DNA recombination
# http://purl.obolibrary.org/obo/GO_0000019 # regulation of mitotic recombination
# http://purl.obolibrary.org/obo/GO_0000023 # maltose metabolic process
# http://purl.obolibrary.org/obo/GO_0000024 # maltose biosynthetic process
# http://purl.obolibrary.org/obo/GO_0000025 # maltose catabolic process
# http://purl.obolibrary.org/obo/GO_0000026 # alpha-1,2-mannosyltransferase activity
# http://purl.obolibrary.org/obo/GO_0000027 # ribosomal large subunit assembly
# ...
